# %% [markdown]
# # Imports

# %%
import os
import zipfile
import json
from scipy import sparse
import numpy as np

# %% [markdown]
# # Dataset path

# %%
datadirectory="/home/leboudy/Downloads/lastfm_subset.zip"
dataset = zipfile.ZipFile(datadirectory)

# %% [markdown]
# # global variables initialization

# %%
songId=0
t=0
g=50
beta=0.2
categories =["Technical Death Metal"]
S =[]
id2songJsonMap = []
id2songIdMap = {}
fhat=[]
n=5 #top songs to report
#limitingCounter = 1000

# %% [markdown]
# # Loading data

# %%
for i in dataset.namelist():
    if  i.endswith(".json"): #songId<limitingCounter and 
        f = json.loads(dataset.read(i).decode("utf-8"))
        if  f["track_id"] not in id2songIdMap.keys():
            id2songIdMap[f["track_id"]] = songId
            tempcategories = set(categories)#will keep removing tags from it
            newtags=[]
            for tag in f["tags"]:#looping over tags
                if int(tag[1]) >g:#filters out those <g
                    newtags.append(tag)#keeping >g
                    if tag[0] in tempcategories:#if it is in the tempcategories
                        tempcategories.remove(tag[0])#removing it
            f["tags"] = newtags
            id2songJsonMap.append(f)
            #songTags= [t[0] for t in f["tags"]]
            #if len(list(filter(lambda x: x in categories,songTags )) ) == len(categories):
            if len(tempcategories)==0:#meaning we encountered all of the tags
                S.append(songId)
                fhat.append(1)
            else:
                fhat.append(0)
            songId+=1

# %% [markdown]
# # initializing the teleportation probablilities

# %%
#_fhat=np.array()
#_fhat.shape=(songId,1)
fhat=(1/len(S))*np.array(fhat)

# %% [markdown]
# # Building the glorious Adjacency matrix

# %%
col=[]
row=[]
data=[]
for i in range( len(id2songJsonMap)):
    for s in id2songJsonMap[i]["similars"]:
        if s[0] in id2songIdMap.keys() and s[1]>=t:
            col.append(i)
            row.append(id2songIdMap[s[0]])
            data.append(1)

# %%
A = sparse.csr_matrix((data, (row, col)),shape=(songId, songId))

# %% [markdown]
# # Randomly initializing r

# %%
r =np.random.rand(A.shape[0])
r=r/np.sum(r)

# %%
print(len(id2songJsonMap))
print (A.shape)
print(songId)
print (len(S))
print (songId)
# Out:
# 9330
# (104212, 104212)
# 9330
# 1
# 9330

# %%
#r = beta * A.multiply(r)+(1-beta)*fhat

# %% [markdown]
# # Power Iterations

# %%
for i in range(100):
    r=A.multiply(beta).dot(r)+fhat*(1-beta)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-27-11ff6e43c715> in <module>()
#       1 for i in range(100):
# ----> 2     r=A.multiply(beta).dot(r)+fhat*(1-beta)
#
# ValueError: operands could not be broadcast together with shapes (104212,) (9330,)

# %% [markdown]
# # Reporting the top n songs

# %%
topIndecs = r.argsort()[-n:][::-1]

# %%
for item in topIndecs:
    print (id2songJsonMap[item]["track_id"])
# Out:
# TRVMQKY128F934B19F
# TRAWCHJ128F9359625
# TRTYIIF128F9300E94
# TRQPGSM128F4228154
# TRJRVKU128F92F162F

# %%
print (topIndecs)
# Out:
# [80249 44278 60033 33989 73126]

# %%
id2songJsonMap[33989 ]
# Out:
# {'artist': 'Buddy Knox',
#  'similars': [['TRLEWSJ128F9332B6E', 1],
#   ['TRGOVUP128F92F1486', 0.846234],
#   ['TRIJUSK128F93265A0', 0.234507],
#   ['TRIDSHO128F42420AA', 0.234507],
#   ['TRAAVJY128F932F932', 0.234507],
#   ['TRPEFWN128F427D524', 0.234507],
#   ['TRPXGNT128F424EBF7', 0.234507],
#   ['TRSTMFV128F92DC91F', 0.234507],
#   ['TRDNSMD12903CA4D91', 0.234507],
#   ['TRDOWXD128EF348C89', 0.234507],
#   ['TRODATP12903CB2394', 0.234507],
#   ['TRKNUNS128F9307B26', 0.234507],
#   ['TRYXKEK128F931EBDD', 0.234507],
#   ['TREQFDB128F4259715', 0.231868],
#   ['TRIEIUL12903D03A9F', 0.230615],
#   ['TRTLRNJ12903CF8A4E', 0.230615],
#   ['TRVFXLR12903CE9528', 0.230615],
#   ['TRMZONN12903CBEB30', 0.22085],
#   ['TRQWKVN128F930F016', 0.22085],
#   ['TRZCCVP128F931FBB5', 0.22085],
#   ['TRPFEMU12903CF8A88', 0.22085],
#   ['TRUWDSR12903CC9D6E', 0.22085],
#   ['TRUHTEI128F92FA1C7', 0.22085],
#   ['TRYACWU12903D0C3E9', 0.22085],
#   ['TROCVRY128F932A4C0', 0.215266],
#   ['TRWQUEV12903CB3AD3', 0.212132],
#   ['TRZQDCH12903CD984E', 0.212132],
#   ['TRPEHXR12903CD2997', 0.212132],
#   ['TRPOOEL128F9349211', 0.212132],
#   ['TRLUWTF128F92F116C', 0.212132],
#   ['TRDFVPU12903CDF5EB', 0.212132],
#   ['TRHMHDW128F4270150', 0.208107],
#   ['TRQORAK128F92FA2FA', 0.208107],
#   ['TRQKEWW128F424A0E4', 0.208107],
#   ['TRZQAKN12903C93D81', 0.208107],
#   ['TRTKEEE128F1493237', 0.208107],
#   ['TRUGCVF128F9349311', 0.208107],
#   ['TRUOEBH128EF34A65C', 0.208107],
#   ['TRJBBXV128F426FE0C', 0.208107],
#   ['TRDXQZE12903CCB464', 0.208107],
#   ['TROWQWX128F422813F', 0.208107],
#   ['TRHFTUX128F93010D0', 0.207837],
#   ['TROJURS128F9333422', 0.207837],
#   ['TRBKRCX128F932864B', 0.200791],
#   ['TRZRJPO128F92EF9C8', 0.200791],
#   ['TRZSBTE12903CD7F93', 0.200791],
#   ['TRXHUJF128F934A815', 0.200791],
#   ['TRKGLHA128F932A533', 0.200791],
#   ['TRQSBOA128F4228381', 0.197159],
#   ['TRTOSHK128F9349883', 0.197159],
#   ['TRJIRPY128F92FEA1A', 0.197159],
#   ['TRRQDQV128F42246F1', 0.18733],
#   ['TRQLWJV128F92FE931', 0.18733],
#   ['TRZXPNL128F932D8D1', 0.18733],
#   ['TRNAAMK128F92F2ABE', 0.18733],
#   ['TRVEJTZ12903CA367C', 0.18733],
#   ['TRVJINI12903CBCCBD', 0.18733],
#   ['TRYYDSC12903CC9D3A', 0.18733],
#   ['TRFABHV128EF34749D', 0.186991],
#   ['TRZFCIJ128F92FDFB2', 0.186721],
#   ['TRPWYBW128F42289BC', 0.186721],
#   ['TRPRJGB128F92ECD23', 0.186721],
#   ['TRPUPOB128F92F13E2', 0.186721],
#   ['TROJGTO128F92FA4EF', 0.132359],
#   ['TRBFFTY12903CD983B', 0.130963],
#   ['TRFXHRV12903CDE7D4', 0.130963],
#   ['TRQNXKB128F4244728', 0.130963],
#   ['TRABRPX12903CF8E61', 0.130963],
#   ['TRATQZO12903CB7548', 0.130963],
#   ['TRJVOHN12903CD299B', 0.130963],
#   ['TRSGPIK128F93298D6', 0.130963],
#   ['TRXNIHC12903CEF5C0', 0.130963],
#   ['TRYWHZP128F9330D93', 0.130963],
#   ['TRCBTTH12903CCBDE9', 0.130828],
#   ['TRCVNUA12903CAE074', 0.130828],
#   ['TRRFIVR128F934D81A', 0.130828],
#   ['TRFUMIS128F9359EA3', 0.130828],
#   ['TRQFXNL128F930108D', 0.130828],
#   ['TRICSQW128F42596AE', 0.130828],
#   ['TRAZNAH128F92F159E', 0.130828],
#   ['TRNKNGR12903CACD74', 0.130828],
#   ['TRSPLEA128F932D511', 0.130828],
#   ['TROEZPY12903CE184B', 0.130828],
#   ['TRXFTQX128F93309F7', 0.130828],
#   ['TRHFWTM128F42283A0', 0.129316],
#   ['TRQNKFX128F4264318', 0.129316],
#   ['TRLNWVN128F9359657', 0.129316],
#   ['TRYWYJD128F92D9DD0', 0.129316],
#   ['TRMQCCL128F9302C8D', 0.129098],
#   ['TRHBTVY128F934DA64', 0.129098],
#   ['TRFHPRM12903CA901E', 0.129098],
#   ['TRQHTNL128F92F2F7A', 0.129098],
#   ['TRIXFHC128F1486A3E', 0.129098],
#   ['TRLFXZS128F9322560', 0.129098],
#   ['TRQLEIH128F42280C3', 0.12846],
#   ['TRQOYFB128F92FC6FD', 0.12846],
#   ['TRPLWVK128F1486A39', 0.12846],
#   ['TRLMDSG128F92FEA1E', 0.12846],
#   ['TRGRDBL128F4269363', 0.128258],
#   ['TRCIVXK128F426936A', 0.128258],
#   ['TRBMMDH12903CF099A', 0.128258],
#   ['TRBCSVE12903D13D5C', 0.128258],
#   ['TRNVBXT128F92E88CB', 0.128258],
#   ['TRXPCDW128F426C1D9', 0.128258],
#   ['TRIGOSL128F429C4DB', 0.126766],
#   ['TRRJAAE12903CD29CF', 0.125049],
#   ['TRRVFSI128EF34A1AE', 0.125049],
#   ['TRHWSJF128F9355930', 0.124455],
#   ['TRZPPRA128F424A12A', 0.124455],
#   ['TRTMYHE12903CF4C03', 0.124455],
#   ['TRXYFMR12903CA9045', 0.124455],
#   ['TRGRDKW128F930E16C', 0.122869],
#   ['TRHKBTK12903CC3187', 0.122869],
#   ['TRCRZLX12903CDB1C2', 0.122869],
#   ['TRJCCQO12903CAB30E', 0.122869],
#   ['TRKQMIB128F932E13F', 0.122869],
#   ['TRKDWRN12903CA7548', 0.122869],
#   ['TRAVXEC12903CA228C', 0.121514],
#   ['TRKMRKB128F424BA99', 0.121514],
#   ['TRMKPXG128F4249D52', 0.12077],
#   ['TRWXOZU128F92DEC51', 0.12077],
#   ['TRGAZBF12903CA904C', 0.12077],
#   ['TRZZKOS128F92F9074', 0.12077],
#   ['TRZKMRS128F9339878', 0.12077],
#   ['TRNSLIX128F93590A6', 0.12077],
#   ['TRLIKCO128F424B242', 0.12077],
#   ['TRLAQSH128F9322576', 0.12077],
#   ['TRXIVCO128F931D863', 0.12077],
#   ['TRYSVIV12903CFB1F5', 0.12077],
#   ['TRYXWJJ128F1494B02', 0.12077],
#   ['TRYXBYW12903C93D7A', 0.12077],
#   ['TRWBSQV128F931D834', 0.118497],
#   ['TRDIDYK128F92E27CC', 0.118497],
#   ['TRDCOBM128F426F4C2', 0.118494],
#   ['TRYSHEV12903CC5DFE', 0.118494],
#   ['TRWFLMW128F92D3531', 0.11811],
#   ['TRQMEBZ12903CB2DC0', 0.117229],
#   ['TRNBBXE128F932ACAC', 0.117229],
#   ['TRUZVWQ128F93588FD', 0.117229],
#   ['TRSPNHM128F426BC55', 0.117229],
#   ['TRPMVTT128F9300F92', 0.116989],
#   ['TRPQKTV12903CE648F', 0.116989],
#   ['TRMWVEG128F428B7AB', 0.116635],
#   ['TRQBQNG128F92FD10C', 0.116635],
#   ['TRZCRQE128F93491D7', 0.116635],
#   ['TRIERNL128F934D815', 0.116635],
#   ['TRAVDII128F9300D3B', 0.116635],
#   ['TRTWBKF12903CD96B6', 0.116635],
#   ['TRJJZWQ12903CDBC02', 0.116635],
#   ['TRDHDYY128F931D8A1', 0.116635],
#   ['TROKEBZ128F423F8CF', 0.116635],
#   ['TRMDJKE128F426CD63', 0.115771],
#   ['TRRCUZK12903CB2E0F', 0.115771],
#   ['TRFVAHS128F931FAEB', 0.115771],
#   ['TRARXNO128F92F3006', 0.115771],
#   ['TRTNSFN128F931D942', 0.115771],
#   ['TRDQYPA128F42280C0', 0.115771],
#   ['TRXZKLA128F935914A', 0.115771],
#   ['TRHNMID128F9340C7D', 0.112563],
#   ['TRHZGZX128F92D2B91', 0.112503],
#   ['TRAGNJD12903CC663C', 0.112503],
#   ['TRWQHAK128F935913C', 0.112025],
#   ['TRVIAUG12903CAAD15', 0.112025],
#   ['TRKGJRU128F422DA0C', 0.112025],
#   ['TRWUKGN12903CDFB56', 0.111544],
#   ['TRFUVQR12903C973EB', 0.111544],
#   ['TRIMALA128F92D2B82', 0.111544],
#   ['TRDMMRF128F42B19B1', 0.111544],
#   ['TRZGFIK128F1453D9B', 0.109484],
#   ['TRLNAOW12903CFB135', 0.109484],
#   ['TRXZKRL128F9349343', 0.109484],
#   ['TRSVIWO128F9359AE6', 0.108312],
#   ['TRJREPU128F931479D', 0.10827],
#   ['TRMJDTQ12903C9FDE0', 0.107911],
#   ['TRBIFCL12903CBA7DD', 0.107911],
#   ['TRNFPWE12903CCCEEF', 0.107911],
#   ['TRSUBDY12903CBC500', 0.107911],
#   ['TRVRHOI12903CB83C3', 0.107911],
#   ['TREQGXE12903CF0A56', 0.10707],
#   ['TRVHSRQ128F934A6E4', 0.10707],
#   ['TRZFEXJ128F9315B1D', 0.106937],
#   ['TROUSJP128F931B0D3', 0.106937],
#   ['TRWFHIL12903CCD294', 0.106705],
#   ['TRSTJVQ128F9322588', 0.102445],
#   ['TRFNVSX128F92F153B', 0.101991],
#   ['TRMCNHH12903CE393A', 0.0980719],
#   ['TRAKZAD128F934A8A1', 0.0980719],
#   ['TRSBSJD128F4286A59', 0.0980719],
#   ['TRBSCBI128F92D0865', 0.0976578],
#   ['TRRQOVR128F1467436', 0.0973301],
#   ['TRXFZZK128F42289B8', 0.0973301],
#   ['TRQHRIG12903CE6ABE', 0.0973011],
#   ['TRMSNTO12903CBC555', 0.0972547],
#   ['TRRADXC128F9342866', 0.0972547],
#   ['TRDMELS12903D067C2', 0.0972547],
#   ['TRQHBTA12903C9776E', 0.0970335],
#   ['TRDUHMM128F934123A', 0.0970335],
#   ['TRWZGXS12903CDCE44', 0.0967484],
#   ['TRFKGTH128F92F181A', 0.0966843],
#   ['TRYSOTZ128F932391B', 0.0966843],
#   ['TRMUIMH12903CBA327', 0.0962671],
#   ['TRGDJPG12903CE04F1', 0.0962671],
#   ['TRDCWGY128F9319B31', 0.0962671],
#   ['TRADZQV128F14A5760', 0.0950188],
#   ['TRWCFMF128F9330DA9', 0.0939511],
#   ['TRPCROD12903D13E20', 0.0939511],
#   ['TRVRZKC128F429ECAD', 0.0939511],
#   ['TRDGHLY12903CDF60D', 0.0939511],
#   ['TRHATRN128F934A8E2', 0.0886723],
#   ['TRQIZDF128F1486A1B', 0.0886723],
#   ['TRQXBCM12903CE0519', 0.0886723],
#   ['TRECJSG128F930E167', 0.0886723],
#   ['TRJPUFA128F9359E9E', 0.0886723],
#   ['TRRFVVW128F4264D27', 0.0885765],
#   ['TRLGZHG128EF34FE48', 0.0862838],
#   ['TRWMOOF128F932D41F', 0.085593],
#   ['TRKOICK128F92F1726', 0.0851962],
#   ['TRMWQRB128F92CCD72', 0.0846383],
#   ['TRTOHLA128F423E511', 0.0846383],
#   ['TRNCJBC128F145B047', 0.0832354],
#   ['TRWNHCW128F92D4F13', 0.082493],
#   ['TRGPUFE128F92CD8C3', 0.082493],
#   ['TRCCEGW128F92FE7DE', 0.0806877],
#   ['TRQQVWR12903CE6C13', 0.0806877],
#   ['TRQLRBG128F92E39AF', 0.0806877],
#   ['TRJKUZH128F92CC9EA', 0.0806877],
#   ['TRSEYDM128F4247CCB', 0.0806877],
#   ['TRXLEMR128F931D8C4', 0.0806877],
#   ['TRZVRYS128F14640AF', 0.0806289],
#   ['TRIUXKA128F92D3818', 0.0806289],
#   ['TRSGIEM128F426BD0A', 0.0806289],
#   ['TRZLSDQ128F92D9DB4', 0.0792403],
#   ['TREBRSZ128F92FA865', 0.0792403],
#   ['TRORWOO128F429B60D', 0.0781145],
#   ['TRKDPPF12903CEC22F', 0.0781145],
#   ['TRFAVWU128F425F77B', 0.077515],
#   ['TRFSAVM128F93291E8', 0.077515],
#   ['TRISMIC128F42739CE', 0.077515],
#   ['TRTHWGS128F42AEE39', 0.077515],
#   ['TRCOYQN128F1457F19', 0.0774884],
#   ['TRUGPEJ128F145B05A', 0.0774884],
#   ['TRHNSVH128F92FD386', 0.0768915],
#   ['TRZJKKZ128F92F8490', 0.0768915],
#   ['TRNPPRA128F92F19AF', 0.0768915],
#   ['TRORFTJ128EF34FDBB', 0.0768915],
#   ['TRIPPIC12903CA3689', 0.0749974],
#   ['TRMLZLB12903CC5D72', 0.0731963],
#   ['TRJJRVT12903CD77BD', 0.0724307],
#   ['TRPKQSS128F9320C71', 0.0721849],
#   ['TRJQUTO128F424BA77', 0.0721849],
#   ['TRCFCYZ128F426E6BE', 0.0719754],
#   ['TRGAVHA12903CE926D', 0.070341],
#   ['TRWQHZM12903CDDB07', 0.0688207],
#   ['TRDDMOB12903C9F9CD', 0.0688207],
#   ['TRXXIYW128F145D0A5', 0.0688207],
#   ['TRQLKEZ128F1462F14', 0.0681722],
#   ['TRVPKVA128F92FA714', 0.0681722]],
#  'tags': [['50s', '100'],
#   ['oldies', '88'],
#   ['rockabilly', '72'],
#   ['rock n roll', '72'],
#   ['Rock and Roll', '52']],
#  'timestamp': '2011-08-03 05:17:15.242109',
#  'title': 'Party Doll',
#  'track_id': 'TRQPGSM128F4228154'}

# %% [markdown]
# {u'artist': u'Dying Fetus',
#  u'similars': [[u'TRKGDUE128F92F0E83', 1],
#   [u'TRKDLCR128F92F0E7F', 0.930181],
#   [u'TRKMKOE128F93094A0', 0.170124],
#   [u'TRYDFZL128F930949E', 0.162543],
#   [u'TRKWQKG128F934BE03', 0.14108],
#   [u'TRSWCRD128F428CDC0', 0.138215],
#   [u'TRRQOBX12903CF5E9A', 0.136527],
#   [u'TRGKQCB128F428CDC8', 0.132306],
#   [u'TRIOJWC128F930D724', 0.131877],
#   [u'TRYKETZ128F92C4061', 0.131466],
#   [u'TROPLWL128F934BE0C', 0.129271],
#   [u'TRKUOPO128F930D721', 0.122794],
#   [u'TRLVJBD128F4290F80', 0.118457],
#   [u'TRMRIIF128F92FE5ED', 0.101842],
#   [u'TRGBOFX128F42774D4', 0.101842],
#   [u'TRWWTTU128F92F1A0A', 0.100679],
#   [u'TRXFRTR12903CF45B0', 0.0987389],
#   [u'TRJYRBC128F934BDBF', 0.0977178],
#   [u'TREDAJV12903CDD706', 0.0931674],
#   [u'TRVHMHB128F4275500', 0.0918334],
#   [u'TRTAVJM12903CF1DD1', 0.0916868],
#   [u'TRPUBDK12903CF1DC9', 0.0907987],
#   [u'TRPTWZH128F4275508', 0.0885968],
#   [u'TRCJBLV12903D03E07', 0.0871354],
#   [u'TRNOMEW12903D03E16', 0.0849296],
#   [u'TRJERZV12903CF1E52', 0.0843221],
#   [u'TRIISZE128F92FE5E1', 0.0819743],
#   [u'TRPRCRM128F4290F82', 0.0813888],
#   [u'TRSIKCJ12903CF4242', 0.0761096],
#   [u'TRQGYBW128F93064AE', 0.0753326],
#   [u'TRPKWLL12903CFA207', 0.0744523],
#   [u'TRVZUTI128F428CE41', 0.0724359],
#   [u'TRFRUJD128F427C208', 0.0714274],
#   [u'TRKMEGQ128F4284795', 0.0706988],
#   [u'TRTARAS12903CBE6D4', 0.0689639],
#   [u'TRCMWCJ12903CDD85F', 0.0689617],
#   [u'TRJZKWM12903CFA206', 0.0689617],
#   [u'TRLAKKM128F423DACE', 0.0685598],
#   [u'TRHNEMQ12903CBE6DE', 0.0666846],
#   [u'TRXAGOI128F93064B8', 0.0660369],
#   [u'TRNNIAW12903D01602', 0.0572348],
#   [u'TRDHHIB128F4242267', 0.0503959],
#   [u'TRPHMAG128F423DBFB', 0.0497767],
#   [u'TRBOSUM12903CF8CCF', 0.043149],
#   [u'TRNMWAE12903CF5CAB', 0.0383058],
#   [u'TRMLBFT12903CF26AB', 0.0365885],
#   [u'TRFZFSL128F934C3BA', 0.00421432],
#   [u'TRXEPSX128F429103E', 0.00385149],
#   [u'TRGSVKS128F4242183', 0.00370507],
#   [u'TRXZKWA128F429103B', 0.00340451],
#   [u'TRQCDZN128F934127B', 0.0030235],
#   [u'TRLHKOV128F9341283', 0.0029796],
#   [u'TRYNIAF128F934C683', 0.0029653],
#   [u'TRUXEIW128F934C600', 0.00213755],
#   [u'TRQUYRH12903CE7466', 0.00207372],
#   [u'TRZYUKY12903CF5BC6', 0.00204379],
#   [u'TRYGCEK128F934B511', 0.00203792],
#   [u'TRWZDOO128F932D43A', 0.0020288],
#   [u'TRLFSCJ128F92DC387', 0.00197012],
#   [u'TRFQOJK12903CFF684', 0.00190903],
#   [u'TRXCANO12903CA0AC9', 0.00184685],
#   [u'TREKHBS128F934C5FA', 0.00182417],
#   [u'TRETJRL12903CA0ACA', 0.00172702],
#   [u'TRPZHYT128F93253C4', 0.00167472],
#   [u'TREIPRB128F92DC38B', 0.00165596],
#   [u'TRSVTFV128F93429F5', 0.00159807],
#   [u'TRRQJCA128F934299C', 0.00159798],
#   [u'TRFQWXP128F93429A5', 0.00159798],
#   [u'TRYMYRX128F424EACF', 0.00159141],
#   [u'TRXVADC12903CFF686', 0.00157535],
#   [u'TRJXOKM128F9342A0D', 0.00156752],
#   [u'TRUKHNI128F426FFF9', 0.00156286],
#   [u'TRMWWSL128F92E6D25', 0.00150441],
#   [u'TRSYCDY12903CF5CA5', 0.00149908],
#   [u'TRTFWQU128F932D439', 0.00149077],
#   [u'TRMAPOB128F427DAFD', 0.00139572],
#   [u'TREUBPH128F427B26C', 0.00136202],
#   [u'TRRWKJM128F934B5DE', 0.00131633],
#   [u'TRDCFGN128F934B5DA', 0.00131632],
#   [u'TRYZAGJ128F424EAD2', 0.00131602],
#   [u'TRIZEGF12903D09FCF', 0.0013008],
#   [u'TRLEERZ128F426B204', 0.00126853]],
#  u'tags': [[u'Technical Death Metal', u'100'],
#   [u'Brutal Death Metal', u'85'],
#   [u'death metal', u'42'],
#   [u'grindcore', u'28'],
#   [u'metal', u'14'],
#   [u'death', u'14'],
#   [u'Technical Brutal Death Metal', u'14'],
#   [u'Ethos Of Coercion', u'14'],
#   [u'nosz kurwa jakie stopy', u'14']],
#  u'timestamp': u'2011-07-30 16:58:31.240734',
#  u'title': u'Ethos of Coercion',
#  u'track_id': u'TRMMMQY128F92F0EA3'}
